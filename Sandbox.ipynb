# %%
print('Hello word')
# Out:
# Hello word

# %%
def clean_heartrate_data(data: list) -> tuple: # is (data:list what we would call typecasting? )
    """
    Clean raw heart-rate data by removing malformed or impossible values.
    """
    cleaned = []

    for value in data:
        if isinstance(value, int): #is this supposed to be a colon? or a comma?
            cleaned.append(value)  #I used 'clean instead of cleaned.. copilot helped me find the "indentation error iw as reciveing"

    return cleaned

# %%
def average(data: list) -> float:
    """
    Calculate average of a list of integers using a for-loop. Assumes data is clean.
    """
    total = 0
    count = 0
    for value in data: 
        total = total + value
        count = count + 1
    
    return total/count

# %%
def median(data: list) -> float:
    """
    """
    hsort = sorted(data)
    n = len(hsort)
    hr_median = n//2
    # I asked goggle for examples of modulo that gave if statemets - if the number was even or odd, what the output would be
    # a recent update to my laptop is missing some of my notes in One Note
    if n % 2 == 1:
        return hsort[hr_median]
    else:
        return((hsort[hr_median -1] + hsort[hr_median])/2)

# %%
def range(data: list) -> float:
    """
    """
    x = sorted(data)
    max_value = x[-1]
    min_value = x[0]

    data_range = max_value - min_value

    return data_range

# %%
    cont_avg = []
    cont_sum = sum(data[:k])
    cont_avg.append({cont_sum/k, .2f})
    for i in range(len(data)-k):
        con_sum += (data[i + k])

    return cont_avg
# Out:
#   Cell In[9], line 3
#     cont_avg.append({cont_sum/k, .2f})
#                                   ^
# SyntaxError: invalid decimal literal

# %%
def run(file: str):
        data = []

with open(file) as file:
    for line in file:
        data.append(line.replace("\n", "")) 
          
    cd = clean_heartrate_data(data)              
print(cd)

# %%
with open("./data/phase0.txt", "r") as file_object:
    for line in file_object:
        line = line.strip()
        if (line == "NO DATA" or line == "" ):
            print(line) 
def clean_heartrate_data(data: list) -> tuple:

    clean_heartrate_data = []
    
    for h in data:
        if(h == "NO DATA" or h == ""):  #I need to find the none''values and NO DATA strings, used or conditional string. I dont need to put a comma or colon here
            data.remove(h)
        else:
            clean_heartrate_data.append(int(h)) #print only the values I need
    
    
    return clean_heartrate_data

# %%
##PhaseZeroHR
list = [69, 75, 84, 79, 72, 69, 93, 91, 72, 76, 69, 71, 60, 63, 67, 58, 63, 61, 65, 66, 62, 61, 63, 61, 78, 62, 60, 59, 75, 65, 64, 60, 60, 63, 62, 68, 63, 61, 66, 56, 56, 54, 54, 54, 79, 68, 55, 55, 67, 58, 62, 60, 62, 70, 60, 55, 55, 57, 57, 56]
new_list = sorted(list)
first_value = new_list[0]
last_value = new_list[-1]

print("smallest hr =",first_value, "largest hr =", last_value)
print(f"range = {last_value - first_value}")

average = sum(new_list)/len(new_list)
print("average=",average)
# Out:
# smallest hr = 54 largest hr = 93
# range = 39
# average= 64.76666666666667
